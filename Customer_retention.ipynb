# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
df =pd.read_excel('customer_retention_dataset.xlsx')

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# # Checking Missing Value

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.isnull().sum().any()
# Out:
# False

# %%
df.isin(['NA','N/A','-',' ','?',' ?']).sum().any()
# Out:
# False

# %%
df.describe(include=object)
# Out:
#        1Gender of respondent 2 How old are you?   \
# count                    269                 269
# unique                     2                   5
# top                   Female         31-40 years
# freq                     181                  81
#
#        3 Which city do you shop online from?  \
# count                                    269
# unique                                    11
# top                                    Delhi
# freq                                      58
#
#        5 Since How Long You are Shopping Online ?  \
# count                                         269
# unique                                          5
# top                                 Above 4 years
# freq                                           98
#
#        6 How many times you have made an online purchase in the past 1 year?  \
# count                                                 269
# unique                                                  6
# ...

# %% [markdown]
# # EDA

# %%
# Exploring Gender of Respondent
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(12,6))

df['1Gender of respondent'].value_counts().plot.pie(explode=[0.025,0.025],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':18}, ax=ax[0],shadow=True)
ax[0].set_title('Gender of respondent Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('1Gender of respondent',data=df,ax=ax[1])
ax[1].set_title('Gender of respondent Distribution',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Gender",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
plt.show()
df['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %% [markdown]
# 67.3%  Female & rest are 32.7% Male respondent.
#
# women are more shopping oriented than men.

# %%
# Exploring Gender of Respondent
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(18,9))

df['2 How old are you? '].value_counts().plot.pie(explode=[0.025,0.025,0.025,0.025,0.025],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':14}, ax=ax[0],shadow=True)
ax[0].set_title('Age of Respondent', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('2 How old are you? ',hue =df['1Gender of respondent'] , data=df,ax=ax[1])
ax[1].set_title('How old are Respondent',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Age of Respondent",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 30)
plt.show()
df['2 How old are you? '].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %% [markdown]
# Observation :
# mainly the female customers are between age group of 21-40 years.
# Male Customers Tendency of online shopping age group of 31-50 years.
# shopping tendency is less for age greater than 51 years old.

# %%
# Exploring How Long You are Shopping Online ?
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set2_r')
f,ax=plt.subplots(1,2,figsize=(20,9))

df['3 Which city do you shop online from?'].value_counts().plot.pie(autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':14}, ax=ax[0],shadow=True)
ax[0].set_title('Shopping Online from City', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('3 Which city do you shop online from?',hue =df['1Gender of respondent'] , data=df,ax=ax[1])
ax[1].set_title('Shopping Online from City Genderwise Tendency ',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Shopping Online from City",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation = 30)
plt.show()
df['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [raw]
# Observation :
# Most Online Shopping Customer belong to Delhi,Greater Noida,Noida,Bangalore.
# Metro city like Delhi,Delhi,Greater Noida,Noida,Bangalore Male have more tendency of online shopping.

# %%
pd.crosstab([df['2 How old are you? ']  ,df['1Gender of respondent']],df["3 Which city do you shop online from?"])
# Out:
# 3 Which city do you shop online from?      Bangalore   Bulandshahr  Delhi  \
# 2 How old are you?  1Gender of respondent
# 21-30 years         Female                         18            0      7
#                     Male                            3            0      5
# 31-40 years         Female                          0            0     10
#                     Male                            0            2      9
# 41-50 yaers         Female                         12            0      1
#                     Male                            0            0     22
# 51 years and above  Female                          3            0      0
#                     Male                            0            0      0
# Less than 20 years  Female                          1            0      0
#                     Male                            0            0      4
#
# 3 Which city do you shop online from?      Ghaziabad  Greater Noida  Gurgaon   \
# ...

# %% [raw]
# more than 51 year and less than 20 year less tendency for shopping

# %%
pd.crosstab([df['5 Since How Long You are Shopping Online ?'] ],df["3 Which city do you shop online from?"],margins=True)
# Out:
# 3 Which city do you shop online from?       Bangalore   Bulandshahr  Delhi  \
# 5 Since How Long You are Shopping Online ?
# 1-2 years                                            0            2      1
# 2-3 years                                           14            0     13
# 3-4 years                                            8            0      8
# Above 4 years                                       12            0     20
# Less than 1 year                                     3            0     16
# All                                                 37            2     58
#
# 3 Which city do you shop online from?       Ghaziabad  Greater Noida  \
# 5 Since How Long You are Shopping Online ?
# 1-2 years                                           5              0
# 2-3 years                                           5              4
# 3-4 years                                           0              7
# Above 4 years                                       3             22
# ...

# %% [raw]
# Online shopping is less popular in cities like Bulandshahr,Merrut and  Moradabad.

# %%
pd.crosstab([df['6 How many times you have made an online purchase in the past 1 year?']  ],df["3 Which city do you shop online from?"])
# Out:
# 3 Which city do you shop online from?               Bangalore   Bulandshahr  \
# 6 How many times you have made an online purcha...
# 11-20 times                                                 12            0
# 21-30 times                                                  0            0
# 31-40 times                                                 11            0
# 41 times and above                                           2            0
# 42 times and above                                           0            0
# Less than 10 times                                          12            2
#
# 3 Which city do you shop online from?               Delhi  Ghaziabad  \
# 6 How many times you have made an online purcha...
# 11-20 times                                             1          1
# 21-30 times                                             1          0
# 31-40 times                                            12         10
# ...

# %% [markdown]
# most of customer making purchase for Less than 10 times belongs to city Bangalore,Delhi,Greater Noida and Noida.

# %%
# How do you access the internet while shopping on-line?
df['7 How do you access the internet while shopping on-line?'] = df['7 How do you access the internet while shopping on-line?'].replace('Mobile internet','Mobile Internet')
plt.rcParams["figure.autolayout"] = True
sns.set_palette('hsv')
f,ax=plt.subplots(1,2,figsize=(20,9))

df['7 How do you access the internet while shopping on-line?'].value_counts().plot.pie(explode=[0.025,0.025,0.025],autopct='%3.1f%%',
                textprops ={ 'fontweight': 'bold','fontsize':14}, ax=ax[0],shadow=True)
ax[0].set_title('Type of Internet Connection', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('7 How do you access the internet while shopping on-line?' , hue = df['6 How many times you have made an online purchase in the past 1 year?'] ,data=df,ax=ax[1])
ax[1].set_title('Type of Internet Connection',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Type of Internet Connection",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Respondent",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.show()
df['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile Internet    189
# Wi-Fi               76
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [raw]
# 70.3% Customers are mobile internet
# 28.3% Customers are WiFi User.
# 1.5% Customers are Dial-up User.
# customers who made online shopping for 41 times and above using Mobile internet.

# %%
# Checking Device and Operating system
pd.crosstab([df['8 Which device do you use to access the online shopping?']  ],df["10 What is the operating system (OS) of your device?\t\t\t\t                                          "],margins=True).style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_205b6_row0_col0,#T_205b6_row0_col1,#T_205b6_row1_col0,#T_205b6_row3_col1,#T_205b6_row3_col2,#T_205b6_row3_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_205b6_row0_col2{
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }#T_205b6_row0_col3{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_205b6_row1_col1{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_205b6_row1_col2{
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }#T_205b6_row1_col3{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_205b6_row2_col0{
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }#T_205b6_row2_col1{
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }#T_205b6_row2_col2{
# ...

# %% [raw]
# No Tablet with IOS operating system.
# most of the customer are desktop & laptop user.
# only 2 Customer with Apple laptop
# no customer with Apple desktop.
# 73 customers using android phone zand 60 customers using Apple Iphone.

# %%
pd.crosstab([df['7 How do you access the internet while shopping on-line?']],df["8 Which device do you use to access the online shopping?"],margins=True).style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_a5d9a_row0_col0{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_a5d9a_row0_col1,#T_a5d9a_row0_col2,#T_a5d9a_row0_col3,#T_a5d9a_row0_col4,#T_a5d9a_row2_col0{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_a5d9a_row1_col0{
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }#T_a5d9a_row1_col1{
#             background-color:  #3b92c1;
#             color:  #000000;
#         }#T_a5d9a_row1_col2{
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }#T_a5d9a_row1_col3,#T_a5d9a_row2_col3{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_a5d9a_row1_col4{
#             background-color:  #197db7;
#             color:  #000000;
#         }#T_a5d9a_row2_col1{
#             background-color:  #a2bcda;
#             color:  #000000;
#         }#T_a5d9a_row2_col2{
# ...

# %% [raw]
# No desktop with WiFi.
# All desktop users using mobile internet or dialup connection.
# 141 Smartphone users 104 using mobile internet and only 37 using WiFi.

# %%
pd.crosstab([df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ']],
            df['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '],margins=True).style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_d3854_row0_col0,#T_d3854_row0_col1,#T_d3854_row0_col3,#T_d3854_row1_col1,#T_d3854_row1_col2,#T_d3854_row1_col4,#T_d3854_row1_col5,#T_d3854_row2_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_d3854_row0_col2{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_d3854_row0_col4{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_d3854_row0_col5{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_d3854_row1_col0{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_d3854_row1_col3,#T_d3854_row2_col1,#T_d3854_row3_col0,#T_d3854_row3_col1,#T_d3854_row3_col2,#T_d3854_row3_col3,#T_d3854_row3_col4,#T_d3854_row3_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_d3854_row2_col0{
#             background-color:  #046096;
# ...

# %% [raw]
# 71 customer arrived online store via application,
# 59 via Direct URL
# 18 Customer Via Email Marketing.
# Display adverts and Social Media marketing have very poor performance in landing customer on online store.

# %%
#Checking Time Spend for Purchase decision and Purchase count in Past 1 Year
pd.crosstab([df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ']  ],
            df['6 How many times you have made an online purchase in the past 1 year?'],margins=True).style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_d922e_row0_col0,#T_d922e_row0_col1,#T_d922e_row0_col2,#T_d922e_row0_col4,#T_d922e_row0_col6,#T_d922e_row1_col1,#T_d922e_row2_col4,#T_d922e_row3_col0,#T_d922e_row3_col3,#T_d922e_row3_col4,#T_d922e_row3_col5{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_d922e_row0_col3,#T_d922e_row1_col5{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_d922e_row0_col5{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_d922e_row1_col0{
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }#T_d922e_row1_col2{
#             background-color:  #e0dded;
#             color:  #000000;
#         }#T_d922e_row1_col3{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_d922e_row1_col4,#T_d922e_row2_col1,#T_d922e_row4_col4{
#             background-color:  #73a9cf;
#             color:  #000000;
# ...

# %% [raw]
# 50 Customers taken more than 15 mins for online shopping
# 15 Customer purchase shopping within less than 1 min,
# 7 customer made shopping less than 10 times in past year.

# %%
pd.crosstab([df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ']  ],
            df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '],margins=True).style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_dfd79_row0_col0,#T_dfd79_row0_col1,#T_dfd79_row0_col3,#T_dfd79_row0_col4,#T_dfd79_row1_col3,#T_dfd79_row2_col0,#T_dfd79_row2_col3,#T_dfd79_row3_col0,#T_dfd79_row3_col2,#T_dfd79_row3_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_dfd79_row0_col2{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_dfd79_row1_col0{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_dfd79_row1_col1,#T_dfd79_row4_col1{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_dfd79_row1_col2{
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }#T_dfd79_row1_col4{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_dfd79_row2_col1{
#             background-color:  #69a5cc;
#             color:  #000000;
#         }#T_dfd79_row2_col2{
# ...

# %% [raw]
# 171 Customer out of total 269 customer Sometimes abandon the shopping cart.
# 123 Customer who has spended more than 15 mins on online shopping store before making purchase decision Abandoned the most
# Customer who has taken 1-5 mins before purchase very leas abandon ratio is there.

# %%
#checking Seller_ProductInfo
plt.figure(figsize = (7,5))
sns.factorplot('20 Complete information on listed seller and product being offered is important for purchase decision.',kind='count',data=df,
               hue='21 All relevant information on listed products must be stated clearly')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # checking Online shopping store customer service requirement related features

# %%
df1 = ['27 Empathy (readiness to assist with queries) towards the customers','28 Being able to guarantee the privacy of the customer',
            '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)','30 Online shopping gives monetary benefit and discounts',
            '31 Enjoyment is derived from shopping online','32 Shopping online is convenient and flexible',
            '33 Return and replacement policy of the e-tailer is important for purchase decision','34 Gaining access to loyalty programs is a benefit of shopping online',
            '35 Displaying quality Information on the website improves satisfaction of customers','36 User derive satisfaction while shopping on a good quality website or application',
            '37 Net Benefit derived from shopping online can lead to users satisfaction','38 User satisfaction cannot exist without trust']

# %%
plt.figure(figsize=(10,60))
plotnumber =1
for i in df1:
    if plotnumber <=12:
        ax = plt.subplot(12,1,plotnumber)
        df[i].value_counts().plot.pie(autopct='%3.1f%%',
                textprops ={'fontweight': 'bold','fontsize':10}, shadow=True)
        plt.title(i,fontsize=10,fontweight ='bold')
        plt.ylabel('')
    plotnumber+=1    
plt.show()

# %% [raw]
# Observation :
# 72.1% Customer strongly agree thinks that companies readiness to assist customer queuries related to product is important factor in purchase decision.
# Pie plot also show that being able to guarantee the privacy of the customer is important silent feature for product selection.
# Another most important for product companies is availability of communication channels.
# Most of people enjoy physical shopping ,
# we can see that for 32% customer enjoyment from online shopping strongly matter and for around 46% customer this online shopping enjoyment do not matter.
# Online shoping is 24/7 available with lot of varities of product and with product return facility.
#  85 % of customer thinks, online shopping is convenient & flexiable than physical shopping.
# 73.6% customer thinks that return & replacement policy of e-seller is important factor for making purchase decision.
# 49.4% customer strongly agree and 29.7% customer agree that displaying quality information on website helps in decision making inturn improves customer statsifcation.
# 45.4% of customer strongly agree over fact that user satisfaction cannot exist without trust.

# %% [markdown]
# # feature related to Customer online shopping experiences

# %%
df2 = ['39 Offering a wide variety of listed product in several category','40 Provision of complete and relevant product information',
            '41 Monetary savings','42 The Convenience of patronizing the online retailer','43 Shopping on the website gives you the sense of adventure',
            '44 Shopping on your preferred e-tailer enhances your social status','45 You feel gratification shopping on your favorite e-tailer',
            '46 Shopping on the website helps you fulfill certain roles','47 Getting value for money spent']

# %%
plt.figure(figsize=(12,60))
plotnumber =1
for i in df2:
    if plotnumber <=9:
        ax = plt.subplot(9,1,plotnumber)
        df[i].value_counts().plot.pie(autopct='%3.1f%%',
                textprops ={'fontweight': 'bold','fontsize':14}, shadow=True)
        plt.title(i,fontsize=10,fontweight ='bold')
        plt.ylabel('')
    plotnumber+=1    
plt.show()

# %% [raw]
# Observation :
# 50.2% Customer strongly agree & 36.4% customer agree that for good online shopping complete and relevant product information.
# 83% customer pursue online shopping for Monetary Savings.
# 37.5 % customers Online shopping on website strongly gives the sense of adventure.
# 55.4% people strongly agree and 30.5% people agree that they prefer online shopping

# %% [markdown]
# # Opinion on Online Shopping Platform Websites by Customer

# %%
df3 = ['Easy to use website or application',
       'Visual appealing web-page layout', 'Wild variety of product on offer',
       'Complete, relevant description information of products',
       'Fast loading website speed of website and application',
       'Reliability of the website or application',
       'Quickness to complete purchase',
       'Availability of several payment options', 'Speedy order delivery ',]

# %%
plt.figure(figsize=(10,80))
plotnumber =1
for i in df3:
    if plotnumber <=12:
        ax = plt.subplot(10,1,plotnumber)
        sns.countplot(df[i])
        plt.title(i,fontsize=15,fontweight ='bold')
        plt.xticks(rotation=90)
        plt.ylabel('')
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [raw]
# Observation :
# 67 customers agree that Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com are Easy to use website or application.
# But if we see all countplot of easy to use application & website Amazon.in and Flipkart got individually 1st Rank*.
# More than 80 customers agree that Amazon.in, Flipkart.com have Visual appealing web-page layout than most of other market players.
# 128 people Amazon.in, Flipkart.com provides wide varity of offer on product.
# 100 customer think that Amazon.in, Flipkart.com provides complete information* compare to others.
# Previously we know that 42.8 % customer strongly agree and 41.6 % customer agree over high loading & processing speed of website.
# Here we can see Majority of people think that loading speed of Amazon.in is fastest while Flipkart.com slowest website to load*.
# In terms of Reliability of website or application again Amazon top list.
# 68 customer think that Amazon.in tops the chart in terms of quickness purchase process compare to others.
# 68 customers think that Amazon.in, Flipkart.com provides several payment options compare to others.
# Amazon.in is much better than other online shopping platform and Flipkart.com worst among all in terms of speed delivery of product.

# %%
pd.crosstab([df['40 Provision of complete and relevant product information']  ],
            df["Complete, relevant description information of products"]).style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_91589_row0_col0,#T_91589_row0_col2,#T_91589_row0_col7,#T_91589_row0_col8,#T_91589_row0_col9,#T_91589_row0_col10,#T_91589_row1_col0,#T_91589_row1_col2,#T_91589_row1_col3,#T_91589_row1_col4,#T_91589_row1_col5,#T_91589_row1_col6,#T_91589_row1_col7,#T_91589_row1_col8,#T_91589_row1_col9,#T_91589_row1_col10,#T_91589_row2_col3,#T_91589_row2_col5,#T_91589_row2_col6,#T_91589_row2_col9,#T_91589_row2_col10,#T_91589_row3_col1,#T_91589_row3_col2,#T_91589_row3_col3,#T_91589_row3_col4,#T_91589_row3_col5,#T_91589_row3_col6,#T_91589_row3_col7,#T_91589_row3_col8{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_91589_row0_col1,#T_91589_row0_col3,#T_91589_row0_col5,#T_91589_row0_col6,#T_91589_row2_col0,#T_91589_row2_col2,#T_91589_row2_col4,#T_91589_row2_col7,#T_91589_row2_col8,#T_91589_row3_col9,#T_91589_row3_col10{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_91589_row0_col4{
# ...

# %%
df4 = ['Privacy of customers’ information',
       'Security of customer financial information',
       'Perceived Trustworthiness',
       'Presence of online assistance through multi-channel',
       'Longer time to get logged in (promotion, sales period)',
       'Longer time in displaying graphics and photos (promotion, sales period)',
       'Late declaration of price (promotion, sales period)',
       'Longer page loading time (promotion, sales period)',
       'Limited mode of payment on most products (promotion, sales period)',
       'Longer delivery period', 'Change in website/Application design',
       'Frequent disruption when moving from one page to another',
       'Website is as efficient as before',
       'Which of the Indian online retailer would you recommend to a friend?']

# %%
plt.figure(figsize=(10,100))
plotnumber =1
for i in df4:
    if plotnumber <=14:
        ax = plt.subplot(14,1,plotnumber)
        sns.countplot(df[i])
        plt.title(i,fontsize=10,fontweight ='bold')
        plt.xticks(rotation=90)
        plt.ylabel('')
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [raw]
# Observation :
# Majority of customers trust Amazon.in more than other shopping platform for Privacy of customers’ information, because customer thinks that gaurantee on privacy of thier information is important for them
# Majority of customer trust Amazon.in followed by Flipkart.in over Security of thier financial information.
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com provide assistance through different multi channel.
# Amazon.in take longer time to logged in while Flipkart.com take least time among all.Longer time to get logged in can annoyed customer.
# Majority of people agree that Amazon.in, Flipkart.com takes longer time in displaying and photos.
# Myntra.com followed by Paytm.com take longer page loading time.
# majority customer agree that Paytm.com takes longest time for delivery compare to others.Most of people want shorter delivery time frame,
# Amazon.in website is as effient as ealier after updation.
# 80 peoples recommanded Amazon.in to their friends.
